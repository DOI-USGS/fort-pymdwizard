# %% [markdown]
# # How to make a FGDC taxonomy section using pymdwizard

# %% [markdown]
# # (Functionality is available from within the GUI application)

# %% [markdown]
# ### Step 1 use ITIS to get a list of species identifiers (TSNs)

# %%
from pymdwizard.core import taxonomy

# %%
taxonomy.search_by_common_name('whitebark pine')
# Out:
#        commonName language     tsn
# 0  whitebark pine  English  183311

# %%
taxonomy.search_by_common_name('pine beetle', as_dataframe=True)
# Out:
#                 commonName language     tsn
# 0      western pine beetle  English  114913
# 1      Mexican pine beetle  English  114912
# 2      Jeffrey pine beetle  English  114915
# 3    lodgepole pine beetle  English  114917
# 4     mountain pine beetle  English  114918
# 5  roundheaded pine beetle  English  114911
# 6     southern pine beetle  English  114914

# %%
taxonomy.search_by_common_name('blister rust')
# Out:
#                 commonName     language     tsn
# 0  white-pine blister rust  unspecified  192053

# %%
taxonomy.search_by_scientific_name("gulo gulo")
# Out:
#       tsn            author               combinedName   kingdom unitInd1  \
# 0  180551  (Linnaeus, 1758)                  Gulo gulo  Animalia     None
# 1  622033  (Linnaeus, 1758)           Gulo gulo luscus  Animalia     None
# 2  622054  (Linnaeus, 1758)             Gulo gulo gulo  Animalia     None
# 3  727054      (Kerr, 1792)            Gulo gulo albus  Animalia     None
# 4  727055    Matschie, 1918  Gulo gulo katschemakensis  Animalia     None
# 5  727056      Elliot, 1904           Gulo gulo luteus  Animalia     None
# 6  727057     Goldman, 1935   Gulo gulo vancouverensis  Animalia     None
#
#   unitInd2 unitInd3 unitInd4 unitName1 unitName2        unitName3 unitName4
# 0     None     None     None      Gulo      gulo             None      None
# 1     None     None     None      Gulo      gulo           luscus      None
# 2     None     None     None      Gulo      gulo             gulo      None
# 3     None     None     None      Gulo      gulo            albus      None
# 4     None     None     None      Gulo      gulo  katschemakensis      None
# 5     None     None     None      Gulo      gulo           luteus      None
# 6     None     None     None      Gulo      gulo   vancouverensis      None

# %% [markdown]
# ## From the queries above we need to make a list of the exact tsns to include

# %%
tsns = [183311, 114918, 192053, 179750, 180551]

# %% [markdown]
# # This hierarchy can be converted into FGDC format with the 'gen_fgdc_taxonomy' function

# %%
fgdc_taxonomy = taxonomy.gen_fgdc_taxoncl(tsns, include_common_names=True)

#lxml is being imported just so that we can print out this node in the notebook
from lxml import etree
print(etree.tostring(fgdc_taxonomy, pretty_print=True).decode())
# Out:
# <taxoncl>
#   <taxonrn>Domain</taxonrn>
#   <taxonrv>Eukaryota</taxonrv>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Plantae</taxonrv>
#     <common>plants</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Viridiplantae</taxonrv>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Streptophyta</taxonrv>
#         <common>land plants</common>
#         <taxoncl>
#           <taxonrn>Superdivision</taxonrn>
#           <taxonrv>Embryophyta</taxonrv>
#           <taxoncl>
#             <taxonrn>Division</taxonrn>
#             <taxonrv>Tracheophyta</taxonrv>
#             <common>vascular plants</common>
#             <common>tracheophytes</common>
#             <taxoncl>
#               <taxonrn>Subdivision</taxonrn>
#               <taxonrv>Spermatophytina</taxonrv>
#               <common>spermatophytes</common>
#               <common>seed plants</common>
#               <taxoncl>
#                 <taxonrn>Class</taxonrn>
#                 <taxonrv>Pinopsida</taxonrv>
#                 <common>conifers</common>
#                 <taxoncl>
#                   <taxonrn>Subclass</taxonrn>
#                   <taxonrv>Pinidae</taxonrv>
#                   <taxoncl>
#                     <taxonrn>Order</taxonrn>
#                     <taxonrv>Pinales</taxonrv>
#                     <common>pines</common>
#                     <taxoncl>
#                       <taxonrn>Family</taxonrn>
#                       <taxonrv>Pinaceae</taxonrv>
#                       <common>pines</common>
#                       <taxoncl>
#                         <taxonrn>Genus</taxonrn>
#                         <taxonrv>Pinus</taxonrv>
#                         <common>pine</common>
#                         <taxoncl>
#                           <taxonrn>Species</taxonrn>
#                           <taxonrv>Pinus albicaulis</taxonrv>
#                           <common>scrub pine</common>
#                           <common>white pine</common>
#                           <common>whitebark pine</common>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Animalia</taxonrv>
#     <common>animals</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Bilateria</taxonrv>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Protostomia</taxonrv>
#         <taxoncl>
#           <taxonrn>Superphylum</taxonrn>
#           <taxonrv>Ecdysozoa</taxonrv>
#           <taxoncl>
#             <taxonrn>Phylum</taxonrn>
#             <taxonrv>Arthropoda</taxonrv>
#             <common>arthropods</common>
#             <taxoncl>
#               <taxonrn>Subphylum</taxonrn>
#               <taxonrv>Hexapoda</taxonrv>
#               <common>hexapods</common>
#               <taxoncl>
#                 <taxonrn>Class</taxonrn>
#                 <taxonrv>Insecta</taxonrv>
#                 <common>insects</common>
#                 <taxoncl>
#                   <taxonrn>Subclass</taxonrn>
#                   <taxonrv>Pterygota</taxonrv>
#                   <common>winged insects</common>
#                   <taxoncl>
#                     <taxonrn>Infraclass</taxonrn>
#                     <taxonrv>Neoptera</taxonrv>
#                     <common>modern, wing-folding insects</common>
#                     <taxoncl>
#                       <taxonrn>Superorder</taxonrn>
#                       <taxonrv>Holometabola</taxonrv>
#                       <taxoncl>
#                         <taxonrn>Order</taxonrn>
#                         <taxonrv>Coleoptera</taxonrv>
#                         <common>beetles</common>
#                         <taxoncl>
#                           <taxonrn>Suborder</taxonrn>
#                           <taxonrv>Polyphaga</taxonrv>
#                           <taxoncl>
#                             <taxonrn>Infraorder</taxonrn>
#                             <taxonrv>Cucujiformia</taxonrv>
#                             <taxoncl>
#                               <taxonrn>Superfamily</taxonrn>
#                               <taxonrv>Curculionoidea</taxonrv>
#                               <taxoncl>
#                                 <taxonrn>Family</taxonrn>
#                                 <taxonrv>Curculionidae</taxonrv>
#                                 <common>snout beetles</common>
#                                 <common>weevils</common>
#                                 <taxoncl>
#                                   <taxonrn>Subfamily</taxonrn>
#                                   <taxonrv>Scolytinae</taxonrv>
#                                   <taxoncl>
#                                     <taxonrn>Genus</taxonrn>
#                                     <taxonrv>Dendroctonus</taxonrv>
#                                     <taxoncl>
#                                       <taxonrn>Species</taxonrn>
#                                       <taxonrv>Dendroctonus ponderosae</taxonrv>
#                                       <common>mountain pine beetle</common>
#                                     </taxoncl>
#                                   </taxoncl>
#                                 </taxoncl>
#                               </taxoncl>
#                             </taxoncl>
#                           </taxoncl>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Deuterostomia</taxonrv>
#         <taxoncl>
#           <taxonrn>Phylum</taxonrn>
#           <taxonrv>Chordata</taxonrv>
#           <common>chordates</common>
#           <taxoncl>
#             <taxonrn>Subphylum</taxonrn>
#             <taxonrv>Vertebrata</taxonrv>
#             <common>vertebrates</common>
#             <taxoncl>
#               <taxonrn>Infraphylum</taxonrn>
#               <taxonrv>Gnathostomata</taxonrv>
#               <taxoncl>
#                 <taxonrn>Superclass</taxonrn>
#                 <taxonrv>Tetrapoda</taxonrv>
#                 <taxoncl>
#                   <taxonrn>Class</taxonrn>
#                   <taxonrv>Aves</taxonrv>
#                   <common>Birds</common>
#                   <taxoncl>
#                     <taxonrn>Order</taxonrn>
#                     <taxonrv>Passeriformes</taxonrv>
#                     <common>Perching Birds</common>
#                     <taxoncl>
#                       <taxonrn>Family</taxonrn>
#                       <taxonrv>Corvidae</taxonrv>
#                       <common>Crows</common>
#                       <common>Jays</common>
#                       <common>Magpies</common>
#                       <taxoncl>
#                         <taxonrn>Genus</taxonrn>
#                         <taxonrv>Nucifraga</taxonrv>
#                         <common>Nutcrackers</common>
#                         <taxoncl>
#                           <taxonrn>Species</taxonrn>
#                           <taxonrv>Nucifraga columbiana</taxonrv>
#                           <common>Clark's Nutcracker</common>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#                 <taxoncl>
#                   <taxonrn>Class</taxonrn>
#                   <taxonrv>Mammalia</taxonrv>
#                   <common>mammals</common>
#                   <taxoncl>
#                     <taxonrn>Subclass</taxonrn>
#                     <taxonrv>Theria</taxonrv>
#                     <taxoncl>
#                       <taxonrn>Infraclass</taxonrn>
#                       <taxonrv>Eutheria</taxonrv>
#                       <taxoncl>
#                         <taxonrn>Order</taxonrn>
#                         <taxonrv>Carnivora</taxonrv>
#                         <common>carnivores</common>
#                         <taxoncl>
#                           <taxonrn>Suborder</taxonrn>
#                           <taxonrv>Caniformia</taxonrv>
#                           <common>dog-like carnivores</common>
#                           <taxoncl>
#                             <taxonrn>Family</taxonrn>
#                             <taxonrv>Mustelidae</taxonrv>
#                             <common>mustelids</common>
#                             <taxoncl>
#                               <taxonrn>Subfamily</taxonrn>
#                               <taxonrv>Mustelinae</taxonrv>
#                               <common>wolverines</common>
#                               <common>martens</common>
#                               <common>weasels</common>
#                               <taxoncl>
#                                 <taxonrn>Genus</taxonrn>
#                                 <taxonrv>Gulo</taxonrv>
#                                 <common>wolverines</common>
#                                 <taxoncl>
#                                   <taxonrn>Species</taxonrn>
#                                   <taxonrv>Gulo gulo</taxonrv>
#                                   <common>Wolverine</common>
#                                 </taxoncl>
#                               </taxoncl>
#                             </taxoncl>
#                           </taxoncl>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Fungi</taxonrv>
#     <common>fungi</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Dikarya</taxonrv>
#       <taxoncl>
#         <taxonrn>Division</taxonrn>
#         <taxonrv>Basidiomycota</taxonrv>
#         <common>basidio's</common>
#         <common>basidiomycetes</common>
#         <common>club fungi</common>
#         <taxoncl>
#           <taxonrn>Subdivision</taxonrn>
#           <taxonrv>Pucciniomycotina</taxonrv>
#           <taxoncl>
#             <taxonrn>Class</taxonrn>
#             <taxonrv>Pucciniomycetes</taxonrv>
#             <taxoncl>
#               <taxonrn>Order</taxonrn>
#               <taxonrv>Pucciniales</taxonrv>
#               <taxoncl>
#                 <taxonrn>Family</taxonrn>
#                 <taxonrv>Cronartiaceae</taxonrv>
#                 <taxoncl>
#                   <taxonrn>Genus</taxonrn>
#                   <taxonrv>Cronartium</taxonrv>
#                   <taxoncl>
#                     <taxonrn>Species</taxonrn>
#                     <taxonrv>Cronartium ribicola</taxonrv>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
# </taxoncl>

# %%
taxonomic_hierarchy = taxonomy.merge_taxons(tsns)
taxonomic_hierarchy
# Out:
# Domain:Eukaryota (tsn=None)
#   Kingdom:Plantae (tsn=202422)
#     Subkingdom:Viridiplantae (tsn=954898)
#     Infrakingdom:Streptophyta (tsn=846494)
#     Superdivision:Embryophyta (tsn=954900)
#       Division:Tracheophyta (tsn=846496)
#         Subdivision:Spermatophytina (tsn=846504)
#             Class:Pinopsida (tsn=500009)
#               Subclass:Pinidae (tsn=954916)
#                     Order:Pinales (tsn=500028)
#                             Family:Pinaceae (tsn=18030)
#                                     Genus:Pinus (tsn=18035)
#                                             Species:Pinus albicaulis (tsn=183311)
#   Kingdom:Animalia (tsn=202423)
#     Subkingdom:Bilateria (tsn=914154)
#     Infrakingdom:Protostomia (tsn=914155)
#     Superphylum:Ecdysozoa (tsn=914158)
#       Phylum:Arthropoda (tsn=82696)
#         Subphylum:Hexapoda (tsn=563886)
#             Class:Insecta (tsn=99208)
#               Subclass:Pterygota (tsn=100500)
#                 Infraclass:Neoptera (tsn=563890)
#                   Superorder:Holometabola (tsn=914213)
#                     Order:Coleoptera (tsn=109216)
#                       Suborder:Polyphaga (tsn=112747)
#                         Infraorder:Cucujiformia (tsn=678305)
#                           Superfamily:Curculionoidea (tsn=114654)
#                             Family:Curculionidae (tsn=114666)
#                               Subfamily:Scolytinae (tsn=678830)
#                                     Genus:Dendroctonus (tsn=114910)
#                                             Species:Dendroctonus ponderosae (tsn=114918)
#     Infrakingdom:Deuterostomia (tsn=914156)
#       Phylum:Chordata (tsn=158852)
#         Subphylum:Vertebrata (tsn=331030)
#         Infraphylum:Gnathostomata (tsn=914179)
#           Superclass:Tetrapoda (tsn=914181)
#             Class:Aves (tsn=174371)
#                     Order:Passeriformes (tsn=178265)
#                             Family:Corvidae (tsn=179665)
#                                     Genus:Nucifraga (tsn=179749)
#                                             Species:Nucifraga columbiana (tsn=179750)
#             Class:Mammalia (tsn=179913)
#               Subclass:Theria (tsn=179916)
#                 Infraclass:Eutheria (tsn=179925)
#                     Order:Carnivora (tsn=180539)
#                       Suborder:Caniformia (tsn=552303)
#                             Family:Mustelidae (tsn=180545)
#                               Subfamily:Mustelinae (tsn=552334)
#                                     Genus:Gulo (tsn=180550)
#                                             Species:Gulo gulo (tsn=180551)
#   Kingdom:Fungi (tsn=555705)
#     Subkingdom:Dikarya (tsn=936287)
#       Division:Basidiomycota (tsn=623881)
#         Subdivision:Pucciniomycotina (tsn=936293)
#             Class:Pucciniomycetes (tsn=936313)
#                     Order:Pucciniales (tsn=936406)
#                             Family:Cronartiaceae (tsn=623891)
#                                     Genus:Cronartium (tsn=192052)
#                                             Species:Cronartium ribicola (tsn=192053)

# %% [markdown]
# # This hierarchy can be converted into FGDC format with the 'gen_fgdc_taxonomy' function

# %%
from lxml import etree
fgdc_taxonomy = taxonomy.gen_fgdc_taxoncl(tsns, include_common_names=True)

print(etree.tostring(fgdc_taxonomy, pretty_print=True).decode())
# Out:
# <taxoncl>
#   <taxonrn>Domain</taxonrn>
#   <taxonrv>Eukaryota</taxonrv>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Plantae</taxonrv>
#     <common>plants</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Viridiplantae</taxonrv>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Streptophyta</taxonrv>
#         <common>land plants</common>
#         <taxoncl>
#           <taxonrn>Superdivision</taxonrn>
#           <taxonrv>Embryophyta</taxonrv>
#           <taxoncl>
#             <taxonrn>Division</taxonrn>
#             <taxonrv>Tracheophyta</taxonrv>
#             <common>vascular plants</common>
#             <common>tracheophytes</common>
#             <taxoncl>
#               <taxonrn>Subdivision</taxonrn>
#               <taxonrv>Spermatophytina</taxonrv>
#               <common>spermatophytes</common>
#               <common>seed plants</common>
#               <taxoncl>
#                 <taxonrn>Class</taxonrn>
#                 <taxonrv>Pinopsida</taxonrv>
#                 <common>conifers</common>
#                 <taxoncl>
#                   <taxonrn>Subclass</taxonrn>
#                   <taxonrv>Pinidae</taxonrv>
#                   <taxoncl>
#                     <taxonrn>Order</taxonrn>
#                     <taxonrv>Pinales</taxonrv>
#                     <common>pines</common>
#                     <taxoncl>
#                       <taxonrn>Family</taxonrn>
#                       <taxonrv>Pinaceae</taxonrv>
#                       <common>pines</common>
#                       <taxoncl>
#                         <taxonrn>Genus</taxonrn>
#                         <taxonrv>Pinus</taxonrv>
#                         <common>pine</common>
#                         <taxoncl>
#                           <taxonrn>Species</taxonrn>
#                           <taxonrv>Pinus albicaulis</taxonrv>
#                           <common>scrub pine</common>
#                           <common>white pine</common>
#                           <common>whitebark pine</common>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Animalia</taxonrv>
#     <common>animals</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Bilateria</taxonrv>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Protostomia</taxonrv>
#         <taxoncl>
#           <taxonrn>Superphylum</taxonrn>
#           <taxonrv>Ecdysozoa</taxonrv>
#           <taxoncl>
#             <taxonrn>Phylum</taxonrn>
#             <taxonrv>Arthropoda</taxonrv>
#             <common>arthropods</common>
#             <taxoncl>
#               <taxonrn>Subphylum</taxonrn>
#               <taxonrv>Hexapoda</taxonrv>
#               <common>hexapods</common>
#               <taxoncl>
#                 <taxonrn>Class</taxonrn>
#                 <taxonrv>Insecta</taxonrv>
#                 <common>insects</common>
#                 <taxoncl>
#                   <taxonrn>Subclass</taxonrn>
#                   <taxonrv>Pterygota</taxonrv>
#                   <common>winged insects</common>
#                   <taxoncl>
#                     <taxonrn>Infraclass</taxonrn>
#                     <taxonrv>Neoptera</taxonrv>
#                     <common>modern, wing-folding insects</common>
#                     <taxoncl>
#                       <taxonrn>Superorder</taxonrn>
#                       <taxonrv>Holometabola</taxonrv>
#                       <taxoncl>
#                         <taxonrn>Order</taxonrn>
#                         <taxonrv>Coleoptera</taxonrv>
#                         <common>beetles</common>
#                         <taxoncl>
#                           <taxonrn>Suborder</taxonrn>
#                           <taxonrv>Polyphaga</taxonrv>
#                           <taxoncl>
#                             <taxonrn>Infraorder</taxonrn>
#                             <taxonrv>Cucujiformia</taxonrv>
#                             <taxoncl>
#                               <taxonrn>Superfamily</taxonrn>
#                               <taxonrv>Curculionoidea</taxonrv>
#                               <taxoncl>
#                                 <taxonrn>Family</taxonrn>
#                                 <taxonrv>Curculionidae</taxonrv>
#                                 <common>snout beetles</common>
#                                 <common>weevils</common>
#                                 <taxoncl>
#                                   <taxonrn>Subfamily</taxonrn>
#                                   <taxonrv>Scolytinae</taxonrv>
#                                   <taxoncl>
#                                     <taxonrn>Genus</taxonrn>
#                                     <taxonrv>Dendroctonus</taxonrv>
#                                     <taxoncl>
#                                       <taxonrn>Species</taxonrn>
#                                       <taxonrv>Dendroctonus ponderosae</taxonrv>
#                                       <common>mountain pine beetle</common>
#                                     </taxoncl>
#                                   </taxoncl>
#                                 </taxoncl>
#                               </taxoncl>
#                             </taxoncl>
#                           </taxoncl>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#       <taxoncl>
#         <taxonrn>Infrakingdom</taxonrn>
#         <taxonrv>Deuterostomia</taxonrv>
#         <taxoncl>
#           <taxonrn>Phylum</taxonrn>
#           <taxonrv>Chordata</taxonrv>
#           <common>chordates</common>
#           <taxoncl>
#             <taxonrn>Subphylum</taxonrn>
#             <taxonrv>Vertebrata</taxonrv>
#             <common>vertebrates</common>
#             <taxoncl>
#               <taxonrn>Infraphylum</taxonrn>
#               <taxonrv>Gnathostomata</taxonrv>
#               <taxoncl>
#                 <taxonrn>Superclass</taxonrn>
#                 <taxonrv>Tetrapoda</taxonrv>
#                 <taxoncl>
#                   <taxonrn>Class</taxonrn>
#                   <taxonrv>Aves</taxonrv>
#                   <common>Birds</common>
#                   <taxoncl>
#                     <taxonrn>Order</taxonrn>
#                     <taxonrv>Passeriformes</taxonrv>
#                     <common>Perching Birds</common>
#                     <taxoncl>
#                       <taxonrn>Family</taxonrn>
#                       <taxonrv>Corvidae</taxonrv>
#                       <common>Crows</common>
#                       <common>Jays</common>
#                       <common>Magpies</common>
#                       <taxoncl>
#                         <taxonrn>Genus</taxonrn>
#                         <taxonrv>Nucifraga</taxonrv>
#                         <common>Nutcrackers</common>
#                         <taxoncl>
#                           <taxonrn>Species</taxonrn>
#                           <taxonrv>Nucifraga columbiana</taxonrv>
#                           <common>Clark's Nutcracker</common>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#                 <taxoncl>
#                   <taxonrn>Class</taxonrn>
#                   <taxonrv>Mammalia</taxonrv>
#                   <common>mammals</common>
#                   <taxoncl>
#                     <taxonrn>Subclass</taxonrn>
#                     <taxonrv>Theria</taxonrv>
#                     <taxoncl>
#                       <taxonrn>Infraclass</taxonrn>
#                       <taxonrv>Eutheria</taxonrv>
#                       <taxoncl>
#                         <taxonrn>Order</taxonrn>
#                         <taxonrv>Carnivora</taxonrv>
#                         <common>carnivores</common>
#                         <taxoncl>
#                           <taxonrn>Suborder</taxonrn>
#                           <taxonrv>Caniformia</taxonrv>
#                           <common>dog-like carnivores</common>
#                           <taxoncl>
#                             <taxonrn>Family</taxonrn>
#                             <taxonrv>Mustelidae</taxonrv>
#                             <common>mustelids</common>
#                             <taxoncl>
#                               <taxonrn>Subfamily</taxonrn>
#                               <taxonrv>Mustelinae</taxonrv>
#                               <common>wolverines</common>
#                               <common>martens</common>
#                               <common>weasels</common>
#                               <taxoncl>
#                                 <taxonrn>Genus</taxonrn>
#                                 <taxonrv>Gulo</taxonrv>
#                                 <common>wolverines</common>
#                                 <taxoncl>
#                                   <taxonrn>Species</taxonrn>
#                                   <taxonrv>Gulo gulo</taxonrv>
#                                   <common>Wolverine</common>
#                                 </taxoncl>
#                               </taxoncl>
#                             </taxoncl>
#                           </taxoncl>
#                         </taxoncl>
#                       </taxoncl>
#                     </taxoncl>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
#   <taxoncl>
#     <taxonrn>Kingdom</taxonrn>
#     <taxonrv>Fungi</taxonrv>
#     <common>fungi</common>
#     <taxoncl>
#       <taxonrn>Subkingdom</taxonrn>
#       <taxonrv>Dikarya</taxonrv>
#       <taxoncl>
#         <taxonrn>Division</taxonrn>
#         <taxonrv>Basidiomycota</taxonrv>
#         <common>basidio's</common>
#         <common>basidiomycetes</common>
#         <common>club fungi</common>
#         <taxoncl>
#           <taxonrn>Subdivision</taxonrn>
#           <taxonrv>Pucciniomycotina</taxonrv>
#           <taxoncl>
#             <taxonrn>Class</taxonrn>
#             <taxonrv>Pucciniomycetes</taxonrv>
#             <taxoncl>
#               <taxonrn>Order</taxonrn>
#               <taxonrv>Pucciniales</taxonrv>
#               <taxoncl>
#                 <taxonrn>Family</taxonrn>
#                 <taxonrv>Cronartiaceae</taxonrv>
#                 <taxoncl>
#                   <taxonrn>Genus</taxonrn>
#                   <taxonrv>Cronartium</taxonrv>
#                   <taxoncl>
#                     <taxonrn>Species</taxonrn>
#                     <taxonrv>Cronartium ribicola</taxonrv>
#                   </taxoncl>
#                 </taxoncl>
#               </taxoncl>
#             </taxoncl>
#           </taxoncl>
#         </taxoncl>
#       </taxoncl>
#     </taxoncl>
#   </taxoncl>
# </taxoncl>
